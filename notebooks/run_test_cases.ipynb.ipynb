# %%
# restart python
# %load_ext autoreload
# %autoreload 2 -p
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
# COMMAND ----------
import os
import sys
import pytest

# Path to your project root (parent of covid_analysis and tests)
PROJECT_ROOT = "/Workspace/Users/rpawar707@outlook.com/azure-databrciks/"

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# Import the test module so we can inject the SparkSession
import transforms_test

# Inject the Databricks SparkSession into the test module
transforms_test.set_spark_session(spark)

# Avoid __pycache__ / rewrite issues under /Workspace
os.environ["PYTHONDONTWRITEBYTECODE"] = "1"
os.environ["PYTEST_ADDOPTS"] = "--assert=plain"

# Run pytest in THIS Python process (so it can use the same SparkSession)
result = pytest.main(
    [
        os.path.join(PROJECT_ROOT, "tests", "transforms_test.py"),
        "-q",
    ]
)

print("pytest exit code:", result)
